# %% [markdown]
# # Sentimental analysis as consumer perception

# %% [markdown]
# ## Analysis is done for recent milk related tweets in Ireland and France

# %%
#Import library first
import pandas as pd
import nltk

# %% [markdown]
# ### Get tweets from Ireland

# %%
#import library first
import requests
import json
from time import sleep

# please add bearer_token here
bearer_token = "Add bearer token here"

# set limit for the sample
sample_limit =500


# file to save tweeter response
FILE = 'tweet_response_irelandtweet.json'
# twitter search api url
search_url = "https://api.twitter.com/2/tweets/search/recent"
#search_url = "https://api.twitter.com/2/tweets/search/all"

# add query paramters here
#change params based on the endpoint you are using
 
query_params = {'query': 'irish milk lang:en -is:retweet',
                'tweet.fields': 'author_id', 
                'max_results': '99',
                'next_token': {}}

#query_params = {'query': 'ireland milk quality lang:en -is:retweet',
 #               'tweet.fields': 'author_id', 
  #              'max_results': '100',
   #             'next_token': {}}

# function to add request header
def bearer_oauth(r):
    r.headers = {"Authorization": "Bearer {}".format(bearer_token)}
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r
# function to send request and recieve response
def connect_to_endpoint(url, params):
    response = requests.get(url, auth=bearer_oauth, params=params)
    #print(response.status_code)
    # check if response code is good or bad
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()




# main function to get tweets
def get_tweets():
    json_response = connect_to_endpoint(search_url, query_params)
    
    # add try block to catch the error
    try:
        #print(json_response)
        returnVal = json_response["meta"]["result_count"]
        #print("Tweet count is: %s" %  returnVal)
        if returnVal > 0:
            json_response = connect_to_endpoint(search_url, query_params)
            json_file = open(FILE, mode='a')
            
            
            #step up to write the file
            #json_file.write('{"data": [')
            
            
            # get data from json node
            json_file.writelines(json.dumps(json_response["data"])[1:-1])
                
            nextToken =""
            
            for post in json_response:
                # check if meta tag is present the json response
                if 'meta' in post:
                        for d in json_response["meta"]:
                            # print(d)
                            if 'next_token' in d:
                                #   print("Next token value iswewe: %s" % json_response['meta']['next_token'])
                                #print(json_response['meta']['next_token'])
                                nextToken=json_response['meta']['next_token']
                                #if nextToken =="":
                                #print(json_response["meta"]["oldest_id"] +
                                        #      "\n" + json_response["meta"]["newest_id"] +
                                        #      "\n" + json_response["meta"]["next_token"])
                                        #print(json_response["meta"]["next_token"])
                                counter = 0
                                tweets_counter = 0
                                tweets_counter += json_response["meta"]["result_count"]
                                                    #print("Next token value is: %s" % json_response["meta"]["next_token"])
                                                    #print("Next token value is: %s" % json_response["meta"]["result_count"])
                                                    # sample limit is 500, so need only 500 tweets
                                while json_response["meta"]["next_token"] and tweets_counter <= sample_limit:
                                    # sleep for 2 seconds to maintain throttling
                                    sleep(2)
                                    json_response = connect_to_endpoint(search_url, query_params)


                                    json_file.writelines("," + json.dumps(json_response["data"])[1:-1])


                                    #print(json_response["meta"]["oldest_id"] +
                                    #    "\n" + json_response["meta"]["newest_id"] +
                                    #   "\n" + json_response["meta"]["next_token"])

                                    print("Tweet count is: %s" %  tweets_counter)
                                    #print("Next token value is: %s" %  json_response["meta"]["next_token"])
                                    #print(json_response)

                                    counter += 1
                                    tweets_counter += json_response["meta"]["result_count"]

                                #json_file.writelines("]}")


                                json_file.close()
        else:
            print("Tweets not found")
    except Exception as e:
        print("Error! error message is: %s" % str(e))

# check if connected to twitter api successfully
if __name__ == "__main__":
    #below function will extract tweets
    get_tweets()
# Out:
# Tweet count is: 97
# Tweet count is: 194
# Tweet count is: 291
# Tweet count is: 388
# Tweet count is: 485

# %% [markdown]
# ### Get tweet from France

# %%
#import library first
import requests
import json
from time import sleep

# please add bearer_token here
bearer_token = "Add bearer token here"

# set limit for the sample
sample_limit =500


# file to save tweeter response
FILE = 'tweet_response_francetweet.json'
# twitter search api url
search_url = "https://api.twitter.com/2/tweets/search/recent"
#search_url = "https://api.twitter.com/2/tweets/search/all"

# add query paramters here
#change params based on the endpoint you are using
 
query_params = {'query': 'french milk lang:en -is:retweet',
                'tweet.fields': 'author_id', 
                'max_results': '99',
                'next_token': {}}

#query_params = {'query': 'ireland milk quality lang:en -is:retweet',
 #               'tweet.fields': 'author_id', 
  #              'max_results': '100',
   #             'next_token': {}}

# function to add request header
def bearer_oauth(r):
    r.headers = {"Authorization": "Bearer {}".format(bearer_token)}
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r
# function to send request and recieve response
def connect_to_endpoint(url, params):
    response = requests.get(url, auth=bearer_oauth, params=params)
    #print(response.status_code)
    # check if response code is good or bad
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()




# main function to get tweets
def get_tweets():
    json_response = connect_to_endpoint(search_url, query_params)
    
    # add try block to catch the error
    try:
        #print(json_response)
        returnVal = json_response["meta"]["result_count"]
        #print("Tweet count is: %s" %  returnVal)
        if returnVal > 0:
            json_response = connect_to_endpoint(search_url, query_params)
            json_file = open(FILE, mode='a')
            
            
            #step up to write the file
            #json_file.write('{"data": [')
            
            
            # get data from json node
            json_file.writelines(json.dumps(json_response["data"])[1:-1])
                
            nextToken =""
            
            for post in json_response:
                # check if meta tag is present the json response
                if 'meta' in post:
                        for d in json_response["meta"]:
                            # print(d)
                            if 'next_token' in d:
                                #   print("Next token value iswewe: %s" % json_response['meta']['next_token'])
                                #print(json_response['meta']['next_token'])
                                nextToken=json_response['meta']['next_token']
                                #if nextToken =="":
                                #print(json_response["meta"]["oldest_id"] +
                                        #      "\n" + json_response["meta"]["newest_id"] +
                                        #      "\n" + json_response["meta"]["next_token"])
                                        #print(json_response["meta"]["next_token"])
                                counter = 0
                                tweets_counter = 0
                                tweets_counter += json_response["meta"]["result_count"]
                                                    #print("Next token value is: %s" % json_response["meta"]["next_token"])
                                                    #print("Next token value is: %s" % json_response["meta"]["result_count"])
                                                    # sample limit is 500, so need only 500 tweets
                                while json_response["meta"]["next_token"] and tweets_counter <= sample_limit:
                                    # sleep for 2 seconds to maintain throttling
                                    sleep(2)
                                    json_response = connect_to_endpoint(search_url, query_params)


                                    json_file.writelines("," + json.dumps(json_response["data"])[1:-1])


                                    #print(json_response["meta"]["oldest_id"] +
                                    #    "\n" + json_response["meta"]["newest_id"] +
                                    #   "\n" + json_response["meta"]["next_token"])

                                    print("Tweet count is: %s" %  tweets_counter)
                                    #print("Next token value is: %s" %  json_response["meta"]["next_token"])
                                    #print(json_response)

                                    counter += 1
                                    tweets_counter += json_response["meta"]["result_count"]

                                #json_file.writelines("]}")


                                json_file.close()
        else:
            print("Tweets not found")
    except Exception as e:
        print("Error! error message is: %s" % str(e))

# check if connected to twitter api successfully
if __name__ == "__main__":
    #below function will extract tweets
    get_tweets()
# Out:
# Tweet count is: 95
# Tweet count is: 190
# Tweet count is: 285
# Tweet count is: 380
# Tweet count is: 475

# %% [markdown]
# # Sentiment Analysis for Milk Related Tweets in Ireland

# %%
# I am using pre-imoported tweet file, this file was extracted on 30.12.2022 at 8.30pm

# %%
# import library first
import pandas as pd
# read json file
# Convert JSON File to CSV File
# pandas read JSON File
ireland_df = pd.read_json('tweet_response_Ireland.json', lines=True)
#df.to_csv('courses.csv')

# %%
ireland_df.head(2)
# Out:
#                                                 text            author_id  \
# 0  Read Where the Crawdads Sing and gulp down som...  1368800100705734656
# 1  40 Br/Irish Fr Spring Calving Heifers (TB4)- U...           1853971129
#
#                     id edit_history_tweet_ids
# 0  1608920248656482304  [1608920248656482304]
# 1  1608907547011940352  [1608907547011940354]

# %%
ireland_df.shape
# Out:
# (594, 4)

# %% [markdown]
# ### Data Pre Processing and Cleaning

# %%
ireland_df.columns # this will list all the column names
# Out:
# Index(['text', 'author_id', 'id', 'edit_history_tweet_ids'], dtype='object')

# %%
ireland_df.head(2)
# Out:
#                                                 text            author_id  \
# 0  Read Where the Crawdads Sing and gulp down som...  1368800100705734656
# 1  40 Br/Irish Fr Spring Calving Heifers (TB4)- U...           1853971129
#
#                     id edit_history_tweet_ids
# 0  1608920248656482304  [1608920248656482304]
# 1  1608907547011940352  [1608907547011940354]

# %%
# Store the column of the dataframe named as "text"
Xval = ireland_df['text']

# %%
# Clean text Data

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

import string
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Luiza
# [nltk_data]     Salek\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Store the stopwords into the object named as "stop_words"
stop_words = stopwords.words('english')

# Store the string.punctuation into an object punct
punct = string.punctuation

# Initialise an object using a method PorterStemmer
stemmer = PorterStemmer()

# %%
import re

cleaned_tweet_data=[]

# For loop from first value to length(X), ^a-zA-Z means include small and capital case letters

for i in range(len(Xval)):
    tweet = re.sub('[^a-zA-Z]', ' ', Xval.iloc[i])
    tweet = tweet.lower().split()
    tweet = [stemmer.stem(word) for word in tweet if (word not in stop_words) and (word not in punct)]
    tweet = ' '.join(tweet)
    cleaned_tweet_data.append(tweet)

# %%
cleaned_tweet_data
# Out:
# ['read crawdad sing gulp milk irish coffe glass',
#  'br irish fr spring calv heifer tb uk well grown group spring calv heifer due feb due march april great opportun purchas strong calf heifer boost milk product http co ji nskg gs http co qdnpeqxgj',
#  'irish carnyx catharinehoey jamiebrysoncpni hope get poison danger pesticid deregul milk probabl nasti hormon improv beef dread chlorin chicken protectionist racket',
#  'heybenjii naughtylilprin nocontextbrit irish even smaller market alot brand food product differ ingredi uk ship food stuff expens make rather import like cadburi chocol tast differ milk tast differ',
#  'accord europeanmilkforum research carri year major irish consum believ meal would less enjoy without milk chees dairi product sustainabledairyeu sustainabledairyireland http co kgkadhk zj http co c evuzrstl',
#  'ok learn invent whiskey irish three hundr year gap invent anyth els next thing chocol milk',
#  'annlesbyphd pleas beeotch whiter soy milk definit whiter german irish',
#  'last week made latk week irish version boxti made leftov mash shred flour milk serv syrup sugar applesauc cream also made garlic steak bite w leftov prime rib yummi boxti leftov http co xyvwdxmwnt',
#  'sleekcomplic true stori kid never knew peopl left milk cooki santa hous alway left irish soda bread amp glass wine carrot reindeer cours',
#  'irish milk tea',
#  'irish milk tea',
#  'holi shit bone coffe make great cold brew oogi boogi irish creme one fantast need lil bit sweetner milk also vibrat',
#  'benonwin littl commi urban shit come mind sad song traitor jame vi scot union fact scum union milk english irish amp welsh everi minut everi day evil evil fact traitor state http co fpmcpbfffh',
#  'drdunderdal glass bailey irish creme look like milk',
#  'forbidden soror neapolitan irish coffe rocki road ice cream serv waffl cone milk chocol shave',
#  'vegan irish coffe secret ingredi oat milk http co rn hufdh',
#  'know done alreadi made super tasti hot chocol mix drink night ago pint glass milk half half shot kahlua shot rumchata shot irish cream',
#  'myfin heaven ya mixtur inspir big lebowski use milk say use cream like irish cream',
#  'milk irish sugar beliz http co exnloyxp l',
#  'irish milk tea',
#  'irish milk tea http co ipuwkn q p',
#  'withoutanecho tbf watch film mayb wanna go live irish ireland like ride around day deliv milk',
#  'read war peac enjoy milk irish coffe glass',
#  'read dracula enjoy delici chocol milk irish coffe glass',
#  'perfect christma cocktail freez coffe choic ice cube tray oz pinnacl whip vodka oz bailey irish cream fill milk half half want creamier drink thank later love bartend friend http co q ueh rszi',
#  'ironfli bailey made wine made cheap irish whiskey process milk sugar littl chocol use knob creak least breakfast champion volatilitysmil',
#  'look mix thing bit see tri irish twist neworlean classic http co aacnvzn recip',
#  'read peter pan drink chill milk irish coffe glass',
#  'irish core last week dad pour milk guin pint glass http co bmwcaczw k',
#  'merri imaginari jesu person birthday gener winter commemor fest forget leav milk cooki better nice irish coffe nosuchperson jesusisnotr justparti',
#  'jess irish line age like milk',
#  'rubberbandit http co pcfx cq',
#  'merri christma due close highway david arriv delay box day doubl shot boozi coffe regular one carolan irish cream tomorrowbrewco doubl coffe milk stout delici merri christma see tomorrow david http co fk oclyv',
#  'irish unionist go souther tayto along southern dairi milk',
#  'mid centuri modern milk glass irish coffe mug set http co uxkzfk frp etsi junkyardblond federalglass http co pmmvqwskij',
#  'receiv k frm ate michel h ate mayet h tita irish huhu hinaot naa pay mohatag pang dapi milk daghannnnnnn',
#  'bread sauc british irish warm cold sauc made milk thicken bread crumb typic eaten roast chicken turkey date back mediev time consid essenti christma tabl http co eundwqk k',
#  'chrishahn yep gone back ukrain xma tell everyon easi milk irish return januari aunt uncl neic nephew toe return ukrain holiday rent properti http co kiubenjwen',
#  'read dracula drink chill chocol milk irish coffe glass',
#  'big guy arriv gave irish cream edibl instead milk cooki',
#  'milk categori provid irish lip dead consider provid http co nnieiyum',
#  'read pride prejudic drink refresh milk irish coffe glass',
#  'caviar black truffl salam wagyu bresaola sheep milk ro umbra irish whiskey cheddar special luxuri chees meat serv day nye prix fix beer board pair noon pm reserv liter otherwis http co py hnkbzz',
#  'irish milk tea http co u hylua lr',
#  'irish milk tea',
#  'liq irish milk tea',
#  'husband left goat provid milk famili howev goat die due drought life realli hard kame amp million other horn africa thank irish aid kame given cash buy food famili http co fbbdxbbut',
#  'accord europeanmilkforum research carri year major irish consum believ meal would less enjoy without milk chees dairi product sustainabledairyeu sustainabledairyireland http co kgkadhk zj http co c evuzrstl',
#  'ok learn invent whiskey irish three hundr year gap invent anyth els next thing chocol milk',
#  'annlesbyphd pleas beeotch whiter soy milk definit whiter german irish',
#  'last week made latk week irish version boxti made leftov mash shred flour milk serv syrup sugar applesauc cream also made garlic steak bite w leftov prime rib yummi boxti leftov http co xyvwdxmwnt',
#  'sleekcomplic true stori kid never knew peopl left milk cooki santa hous alway left irish soda bread amp glass wine carrot reindeer cours',
#  'irish milk tea',
#  'irish milk tea',
#  'holi shit bone coffe make great cold brew oogi boogi irish creme one fantast need lil bit sweetner milk also vibrat',
#  'benonwin littl commi urban shit come mind sad song traitor jame vi scot union fact scum union milk english irish amp welsh everi minut everi day evil evil fact traitor state http co fpmcpbfffh',
#  'drdunderdal glass bailey irish creme look like milk',
#  'forbidden soror neapolitan irish coffe rocki road ice cream serv waffl cone milk chocol shave',
#  'vegan irish coffe secret ingredi oat milk http co rn hufdh',
#  'know done alreadi made super tasti hot chocol mix drink night ago pint glass milk half half shot kahlua shot rumchata shot irish cream',
#  'myfin heaven ya mixtur inspir big lebowski use milk say use cream like irish cream',
#  'milk irish sugar beliz http co exnloyxp l',
#  'irish milk tea',
#  'irish milk tea http co ipuwkn q p',
#  'withoutanecho tbf watch film mayb wanna go live irish ireland like ride around day deliv milk',
#  'read war peac enjoy milk irish coffe glass',
#  'read dracula enjoy delici chocol milk irish coffe glass',
#  'perfect christma cocktail freez coffe choic ice cube tray oz pinnacl whip vodka oz bailey irish cream fill milk half half want creamier drink thank later love bartend friend http co q ueh rszi',
#  'ironfli bailey made wine made cheap irish whiskey process milk sugar littl chocol use knob creak least breakfast champion volatilitysmil',
#  'look mix thing bit see tri irish twist neworlean classic http co aacnvzn recip',
#  'read peter pan drink chill milk irish coffe glass',
#  'irish core last week dad pour milk guin pint glass http co bmwcaczw k',
#  'merri imaginari jesu person birthday gener winter commemor fest forget leav milk cooki better nice irish coffe nosuchperson jesusisnotr justparti',
#  'jess irish line age like milk',
#  'rubberbandit http co pcfx cq',
#  'merri christma due close highway david arriv delay box day doubl shot boozi coffe regular one carolan irish cream tomorrowbrewco doubl coffe milk stout delici merri christma see tomorrow david http co fk oclyv',
#  'irish unionist go souther tayto along southern dairi milk',
#  'mid centuri modern milk glass irish coffe mug set http co uxkzfk frp etsi junkyardblond federalglass http co pmmvqwskij',
#  'elizabethv irish start day cup tea splash milk wear earplug sleep sleep nice focu heartbeat',
#  'slim glass irish cream mix milk ice inebri like stare hand laugh harder rank game take hardest sleep ever year long clink clink',
#  'read crawdad sing drink refresh chocol milk irish coffe glass',
#  'kg beef aviva stadium irish condit free sunshin energi free rainfal water grow tonn grass produc litr milk similar effec beef bit accuraci pleas http co rhzwafebbj',
#  'irish milk tea',
# ...
#  'irish milk tea http co u hylua lr',
#  'irish milk tea',
#  'liq irish milk tea',
#  'husband left goat provid milk famili howev goat die due drought life realli hard kame amp million other horn africa thank irish aid kame given cash buy food famili http co fbbdxbbut',
#  'accord europeanmilkforum research carri year major irish consum believ meal would less enjoy without milk chees dairi product sustainabledairyeu sustainabledairyireland http co kgkadhk zj http co c evuzrstl',
#  'ok learn invent whiskey irish three hundr year gap invent anyth els next thing chocol milk',
#  'annlesbyphd pleas beeotch whiter soy milk definit whiter german irish',
#  'last week made latk week irish version boxti made leftov mash shred flour milk serv syrup sugar applesauc cream also made garlic steak bite w leftov prime rib yummi boxti leftov http co xyvwdxmwnt',
#  'sleekcomplic true stori kid never knew peopl left milk cooki santa hous alway left irish soda bread amp glass wine carrot reindeer cours',
#  'irish milk tea',
#  'irish milk tea',
#  'holi shit bone coffe make great cold brew oogi boogi irish creme one fantast need lil bit sweetner milk also vibrat',
#  'benonwin littl commi urban shit come mind sad song traitor jame vi scot union fact scum union milk english irish amp welsh everi minut everi day evil evil fact traitor state http co fpmcpbfffh',
#  'drdunderdal glass bailey irish creme look like milk',
#  'forbidden soror neapolitan irish coffe rocki road ice cream serv waffl cone milk chocol shave',
#  'vegan irish coffe secret ingredi oat milk http co rn hufdh',
#  'know done alreadi made super tasti hot chocol mix drink night ago pint glass milk half half shot kahlua shot rumchata shot irish cream',
#  'myfin heaven ya mixtur inspir big lebowski use milk say use cream like irish cream',
#  'milk irish sugar beliz http co exnloyxp l',
#  'irish milk tea',
#  'irish milk tea http co ipuwkn q p',
#  'withoutanecho tbf watch film mayb wanna go live irish ireland like ride around day deliv milk',
#  'read war peac enjoy milk irish coffe glass',
#  'read dracula enjoy delici chocol milk irish coffe glass',
#  'perfect christma cocktail freez coffe choic ice cube tray oz pinnacl whip vodka oz bailey irish cream fill milk half half want creamier drink thank later love bartend friend http co q ueh rszi',
#  'ironfli bailey made wine made cheap irish whiskey process milk sugar littl chocol use knob creak least breakfast champion volatilitysmil',
#  'look mix thing bit see tri irish twist neworlean classic http co aacnvzn recip',
#  'read peter pan drink chill milk irish coffe glass',
#  'irish core last week dad pour milk guin pint glass http co bmwcaczw k',
#  'merri imaginari jesu person birthday gener winter commemor fest forget leav milk cooki better nice irish coffe nosuchperson jesusisnotr justparti',
#  'jess irish line age like milk',
#  'rubberbandit http co pcfx cq',
#  'merri christma due close highway david arriv delay box day doubl shot boozi coffe regular one carolan irish cream tomorrowbrewco doubl coffe milk stout delici merri christma see tomorrow david http co fk oclyv',
#  'irish unionist go souther tayto along southern dairi milk',
#  'mid centuri modern milk glass irish coffe mug set http co uxkzfk frp etsi junkyardblond federalglass http co pmmvqwskij',
#  'look mix thing bit see tri irish twist neworlean classic http co aacnvzn recip',
#  'read peter pan drink chill milk irish coffe glass',
#  'irish core last week dad pour milk guin pint glass http co bmwcaczw k',
#  'merri imaginari jesu person birthday gener winter commemor fest forget leav milk cooki better nice irish coffe nosuchperson jesusisnotr justparti',
#  'jess irish line age like milk',
#  'rubberbandit http co pcfx cq',
#  'merri christma due close highway david arriv delay box day doubl shot boozi coffe regular one carolan irish cream tomorrowbrewco doubl coffe milk stout delici merri christma see tomorrow david http co fk oclyv',
#  'irish unionist go souther tayto along southern dairi milk',
#  'mid centuri modern milk glass irish coffe mug set http co uxkzfk frp etsi junkyardblond federalglass http co pmmvqwskij',
#  'receiv k frm ate michel h ate mayet h tita irish huhu hinaot naa pay mohatag pang dapi milk daghannnnnnn',
#  'bread sauc british irish warm cold sauc made milk thicken bread crumb typic eaten roast chicken turkey date back mediev time consid essenti christma tabl http co eundwqk k',
#  'chrishahn yep gone back ukrain xma tell everyon easi milk irish return januari aunt uncl neic nephew toe return ukrain holiday rent properti http co kiubenjwen',
#  'read dracula drink chill chocol milk irish coffe glass',
#  'big guy arriv gave irish cream edibl instead milk cooki',
#  'milk categori provid irish lip dead consider provid http co nnieiyum',
#  'irish spirit team would like wish merri christma popular tradit leav cooki milk help mr clau travel christma ireland tradit leav tasti minc pie guin wash http co ziev tddpt',
#  'today line meat chicken matook irish bread rice liver sausag soda torero beer sub salad milk malo kases',
#  'fredsarg ye harvey milk black irish latino tran woman']

# %%
# import cleaned tweet to a new data frame
Ire_tweet_df = pd.DataFrame(cleaned_tweet_data, columns = ['tweetText'])

print(Ire_tweet_df)
print(type(Ire_tweet_df))
# Out:
#                                              tweetText
# 0        read crawdad sing gulp milk irish coffe glass
# 1    br irish fr spring calv heifer tb uk well grow...
# 2    irish carnyx catharinehoey jamiebrysoncpni hop...
# 3    heybenjii naughtylilprin nocontextbrit irish e...
# 4    vegan irish coffe secret ingredi oat milk http...
# ..                                                 ...
# 589  big guy arriv gave irish cream edibl instead m...
# 590  milk categori provid irish lip dead consider p...
# 591  irish spirit team would like wish merri christ...
# 592  today line meat chicken matook irish bread ric...
# 593  fredsarg ye harvey milk black irish latino tra...
#
# [594 rows x 1 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
# import library
from textblob import TextBlob

# %%
#function to get subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# %%
#function to get polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
# get subjectivity and add to new column
Ire_tweet_df["Subjectivity"] = Ire_tweet_df['tweetText'].apply(lambda x: getSubjectivity(x))

# %%
# get Polarity and add to new column
Ire_tweet_df["Polarity"] = Ire_tweet_df['tweetText'].apply(lambda x: getPolarity(x))

# %%
Ire_tweet_df.head(5)
# Out:
#                                            tweetText  Subjectivity  Polarity
# 0      read crawdad sing gulp milk irish coffe glass      0.000000  0.000000
# 1  br irish fr spring calv heifer tb uk well grow...      0.446667  0.196667
# 2  irish carnyx catharinehoey jamiebrysoncpni hop...      0.475000 -0.300000
# 3  heybenjii naughtylilprin nocontextbrit irish e...      0.250000  0.000000
# 4  vegan irish coffe secret ingredi oat milk http...      0.350000 -0.200000

# %%
Ire_tweet_df.tail(5)
# Out:
#                                              tweetText  Subjectivity  Polarity
# 589  big guy arriv gave irish cream edibl instead m...      0.050000  0.000000
# 590  milk categori provid irish lip dead consider p...      0.200000 -0.100000
# 591  irish spirit team would like wish merri christ...      0.450000  0.300000
# 592  today line meat chicken matook irish bread ric...      0.475000 -0.300000
# 593  fredsarg ye harvey milk black irish latino tra...      0.216667 -0.083333

# %%
# create function to analyse the tweet
def Analysis(score):
    if score < 0:
        return 'negative'
    elif score == 0:
        return 'neutral'
    else:
        return 'positive'

# %%
# create column and apply the analysis
Ire_tweet_df['twtsentiment'] = Ire_tweet_df['Polarity'].apply(Analysis)

# %%
Ire_tweet_df.head(5)
# Out:
#                                            tweetText  Subjectivity  Polarity  \
# 0      read crawdad sing gulp milk irish coffe glass      0.000000  0.000000
# 1  br irish fr spring calv heifer tb uk well grow...      0.446667  0.196667
# 2  irish carnyx catharinehoey jamiebrysoncpni hop...      0.475000 -0.300000
# 3  heybenjii naughtylilprin nocontextbrit irish e...      0.250000  0.000000
# 4  vegan irish coffe secret ingredi oat milk http...      0.350000 -0.200000
#
#   twtsentiment
# 0      neutral
# 1     positive
# 2     negative
# 3      neutral
# 4     negative

# %% [markdown]
# #### Visualize the tweet polarity result

# %%
# assign variables here
totalTweets=0
positive = 0
negative = 0
neutral = 0
# get the value into variable
totalTweets = len(Ire_tweet_df["twtsentiment"])
for twtsentiment in Ire_tweet_df["twtsentiment"]:
    if twtsentiment == "negative":
        negative += 1
    elif twtsentiment == "positive":
        positive += 1
    elif twtsentiment == "neutral":
        neutral += 1

# %%
# print the return value
print("total number: ",totalTweets)
print("positive number: ",positive)
print("negative number: ", negative)
print("neutral number: ",neutral)
# Out:
# total number:  594
# positive number:  186
# negative number:  120
# neutral number:  288

# %%
# create function to calculate percentage
def percentage(part, whole):
    percentage = 100 * float(part)/float(whole)
    
    return ("{:.2f}".format(percentage))

# %%
# calculate percentage
positivePercentage = percentage(positive, totalTweets)
negativePercentage = percentage(negative, totalTweets)
neutralPercentage = percentage(neutral, totalTweets)

# %%
# print values here
print("total tweet: ",totalTweets)
print("positive tweet %: ",positivePercentage)
print("negative tweet %: ", negativePercentage)
print("neutral tweet %: ",neutralPercentage)
# Out:
# total tweet:  594
# positive tweet %:  31.31
# negative tweet %:  20.20
# neutral tweet %:  48.48

# %%
# import library
import matplotlib.pyplot as plt
import seaborn as sns

#Creating PieCart
labels = ['Positive ['+str(positivePercentage)+'%]' , 'Neutral ['+str(neutralPercentage)+'%]','Negative ['+str(negativePercentage)+'%]']
sizes = [positivePercentage,neutralPercentage, negativePercentage]
colors = ['yellowgreen', 'blue','red']
patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(labels)
plt.title("Sentiment Analysis Result for Milk Related Tweets in Ireland" )
plt.axis('equal')
plt.show()

# %%
# Store X the column of the dataframe named as "text"
X = Ire_tweet_df['tweetText']

# %%
# Store y the column if the dataframe named as  "airline_sentiment"
y = Ire_tweet_df['twtsentiment']

# %%
y.head()
# Out:
# 0     neutral
# 1    positive
# 2    negative
# 3     neutral
# 4    negative
# Name: twtsentiment, dtype: object

# %%
# Collect all columns into dataframe named as sentiment_ordering
sentiment_ordering = ['negative', 'neutral', 'positive']

# store all values into column named as "y"
y = y.apply(lambda x: sentiment_ordering.index(x))

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    0
# 3    1
# 4    0
# Name: twtsentiment, dtype: int64

# %% [markdown]
# ### Bag of Words using CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Instantiate an object cv by calling a method named as CountVectorzer()
cv    = CountVectorizer(max_features = 3000, stop_words = ['milk', 'price'])

# Train the dataset by calling a fit_transform() method
X_fin = cv.fit_transform(X).toarray()

# Display the rows and colums
X_fin.shape
# Out:
# (594, 1014)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split

# Instantiate an object model by calling a method MultinomialNB()
model = MultinomialNB()

# %%
# Split the dataset into training and testing parts
X_train, X_test, y_train, y_test = train_test_split(X_fin, y, test_size = 0.3)

# %%
# Train the model by calling a method fit()
model.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
# Call predict() method
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# Instantiate a mthod named as Cla
cf = classification_report(y_test, y_pred)

# Display the values of an object cf
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        34
#            1       1.00      1.00      1.00        90
#            2       1.00      1.00      1.00        55
#
#     accuracy                           1.00       179
#    macro avg       1.00      1.00      1.00       179
# weighted avg       1.00      1.00      1.00       179

# %% [markdown]
# ### Feature Generation using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Create an object 'tf' by calling a method TfidfVectorizer()
tfidf = TfidfVectorizer(max_features = 3000, stop_words = ['milk', 'price'])

# Train the dataset by calling a method fit_tranform() 
X_tfidf = tfidf.fit_transform(X).toarray()

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split

# Instantiate an object model by calling a method MultinomialNB()
model_tdidf = MultinomialNB()

# %%
# Split the dataset into training and testing parts
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size = 0.3)

# %%
# Train the model by calling a method fit()
model_tdidf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Call predict() method
y_pred = model_tdidf.predict(X_test)

# %%
from sklearn.metrics import classification_report

# Instantiate a mathod named as Cla
cf = classification_report(y_test, y_pred)

# Display the values of an object cf
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        37
#            1       0.96      1.00      0.98        90
#            2       1.00      0.94      0.97        52
#
#     accuracy                           0.98       179
#    macro avg       0.99      0.97      0.98       179
# weighted avg       0.98      0.98      0.98       179

# %% [markdown]
# # Sentiment Analysis for Milk Related Tweets in France

# %%
# I am using pre-imoported tweet file, this file was extracted on 31.12.2022 at 11.59pm

# %%
# read json file
# Convert JSON File to CSV File
# pandas read JSON File
france_df = pd.read_json('tweet_response_France.json', lines=True)
#df.to_csv('courses.csv')

# %%
france_df.head(2)
# Out:
#     author_id edit_history_tweet_ids  \
# 0  1050270810  [1609213267205029890]
# 1  1979123587  [1609195247791214595]
#
#                                                 text                   id
# 0  "The Drop of Milk in Belleville: The Christmas...  1609213267205029888
# 1  French Delight - Café au Lait!: Drown your caf...  1609195247791214592

# %%
france_df.shape
# Out:
# (576, 4)

# %% [markdown]
# ### Data Pre Processing and Cleaning

# %%
france_df.columns # this will list all the column names
# Out:
# Index(['author_id', 'edit_history_tweet_ids', 'text', 'id'], dtype='object')

# %%
france_df.head(2)
# Out:
#     author_id edit_history_tweet_ids  \
# 0  1050270810  [1609213267205029890]
# 1  1979123587  [1609195247791214595]
#
#                                                 text                   id
# 0  "The Drop of Milk in Belleville: The Christmas...  1609213267205029888
# 1  French Delight - Café au Lait!: Drown your caf...  1609195247791214592

# %%
# Store the column of the dataframe named as "text"
Xval = france_df['text']

# %%
# Clean text Data

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

import string
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Luiza
# [nltk_data]     Salek\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Store the stopwords into the object named as "stop_words"
stop_words = stopwords.words('english')

# Store the string.punctuation into an object punct
punct = string.punctuation

# Initialise an object using a method PorterStemmer
stemmer = PorterStemmer()

# %%
import re

cleaned_tweet_data=[]

# For loop from first value to length(X), ^a-zA-Z means include small and capital case letters

for i in range(len(Xval)):
    tweet = re.sub('[^a-zA-Z]', ' ', Xval.iloc[i])
    tweet = tweet.lower().split()
    tweet = [stemmer.stem(word) for word in tweet if (word not in stop_words) and (word not in punct)]
    tweet = ' '.join(tweet)
    cleaned_tweet_data.append(tweet)

# %%
cleaned_tweet_data
# Out:
# ['drop milk bellevil christma tree dispensari oil canva henri jule jean geoffroy french http co w biohai',
#  'french delight caf au lait drown caffein crave oh french delight caf au lait heavenli recip perfect combin steam milk strong hot coffe transport straight http co dwta dcjrr',
#  'french cow milk chees petit livarot oz szvjn u http co welwjfjheo http co b qkvfsek',
#  'kateatherley use eggnog instead milk make french toast',
#  'chines french nft enthusiast golden milk lover introvert bone',
#  'carykelli joewbowl plan tri make chees get back farmer market sell raw milk usual sell raw butter done french style slightli ferment delici cheesi butter',
#  'holiday menu santa milk amp cooki el amp n hot chocol spice orang amp white chocol french toast http co bseourxkt',
#  'thank loui pasteur th centuri french biologist milk drink today contain littl bacteria',
#  'cowboyenjoy sound good howev appetit sinc usual drink milk coffe pastri french way',
#  'french toast crunch bacon bacon side milk drink',
#  'nowplay sur radioolympiad gut feat milk coffe amp sugar patric want back french version http co rejybr jgm',
#  'iron stomach life eat weird dirti third world food issu year usa food intoler milk wheat never food allergi life french descent genet reason case http co mhpbxljgp',
#  'tweetsoftea favourit tea silki french vanilla tast heavi yummi tri milk http co heav rlggq',
#  'zulay premium french press coffe pot milk frother set cup oz coffe press glass caraf power doubl bxcsxxt http co hs c xz http co lkthtvoig',
#  'order loveleeski strawberri milk whole cake french toast plushi dear aki thank patient heheh hope alway sleep well cold pillow also eat ton delici food anon http co bhchrbneni http co dlf cpjb',
#  'mayb drink though like milk magic break curs turn loaf french bread http co prtzohnta',
#  'asagikurosagi hmm futur may get one like cu alway tri make homemad capuccino use italian espresso maker coffe french press froth milk alway end ass',
#  'tweetsoftea sweet french vanilla made infus coconut tea leav milk take year make http co vosxtqcpex',
#  'ncontextdogu chines french nft enthusiast golden milk lover introvert bone',
#  'tomorrow go read ordin whilst eat caramel dairi milk watch vicar dibley day class discern ye dawn french want priest',
#  'rickyricksmus bacon cow milk chees green bean casserold muhsroom french fri onion top cool',
#  'pour french vanilla coffe creamer cereal instead almond milk',
#  'cheeseboard panetton french toast panetton soak mixtur egg milk grate cheddar red leicest fri flip top brie flip melt brie serv sprinkl chop toast walnut homemad cranberri sauc http co rqbomasuqr',
#  'dabbinbeeb french press freshli hand ground make work gotten place drink close cup coffe day dad die threw drip coffe maker two tsp cane sugar amp cup unsweeten soy milk',
#  'what alway horni usual found four andrea sweeet come see http co xfw lhkagb brace french redhead milk sph http co djr rccjh',
#  'yung french roast drip coffe saka yung fortifi milk sa ref lasang latt ng sb liter need figur shop buy sauc syrup para alam ko naaa',
#  'french blue chees similar stilton made ewe milk trivia',
#  'dineenchuck mwi lcox quippl numbersmunch guess could brought milk bread make french toast see headlin cruz spoil tx woman brekki http co u waqrvblg',
#  'maxim de pari assort chocol truffl count gift box dark amp milk french chocolat import pralin ganach ca bovqezg http co wxdhk wicd http co fwiqtncayh',
#  'delici coconut milk french vanilla creamer ounc dairi soy coconut cashew almond altern french vanilla cre pgppvex http co e nq n u http co weveuvqg',
#  'chines french nft enthusiast golden milk lover introvert bone',
#  'klhick cold brew ice splash oat milk french vanilla syrup',
#  'miguela nedraza cagovernor wtf give chocol milk issu give donut pastri french toast stick pizza etc need chocol milk top obes nation disgust offer food children',
#  'upuouo emmanuelmacron mahnazshirali rant canada jasonmbrodski kshahrooz injaneb nazaninboniadi pahlavireza khomeini french made frankenstein deliv iran airfranc set islam republ surpris milk creatur till last drop',
#  'elimin diet drop first pork chicken beef egg wine coffe milk nut bread strawberri blueberri french fri corn tortilla banana ketchup tomato sweet pepper carrot onion cilantro sweet potato biscuit ice cream chocol amp ms cheesecak',
#  'person arab kona turkish latt almond milk peppermint cold brew french black http co tsh qh nfz',
#  'bela bath amp beauti oatmeal milk amp bran tripl french mill moistur soap bar harsh ingredi oz pack http co ehveuv k k']

# %%
# import cleaned tweet to a new data frame
French_tweet_df = pd.DataFrame(cleaned_tweet_data, columns = ['tweetText'])

print(French_tweet_df)
print(type(French_tweet_df))
# Out:
#                                              tweetText
# 0    drop milk bellevil christma tree dispensari oi...
# 1    french delight caf au lait drown caffein crave...
# 2    french cow milk chees petit livarot oz szvjn u...
# 3    kateatherley use eggnog instead milk make fren...
# 4    chines french nft enthusiast golden milk lover...
# ..                                                 ...
# 571  miguela nedraza cagovernor wtf give chocol mil...
# 572  upuouo emmanuelmacron mahnazshirali rant canad...
# 573  elimin diet drop first pork chicken beef egg w...
# 574  person arab kona turkish latt almond milk pepp...
# 575  bela bath amp beauti oatmeal milk amp bran tri...
#
# [576 rows x 1 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
# import library 
from textblob import TextBlob

# %%
#function to get subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# %%
#function to get polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
# get subjectivity and add to new column
French_tweet_df["Subjectivity"] = French_tweet_df['tweetText'].apply(lambda x: getSubjectivity(x))

# %%
# get Polarity and add to new column
French_tweet_df["Polarity"] = French_tweet_df['tweetText'].apply(lambda x: getPolarity(x))

# %%
French_tweet_df.head(5)
# Out:
#                                            tweetText  Subjectivity  Polarity
# 0  drop milk bellevil christma tree dispensari oi...      0.000000  0.000000
# 1  french delight caf au lait drown caffein crave...      0.497222  0.313889
# 2  french cow milk chees petit livarot oz szvjn u...      0.083333 -0.066667
# 3  kateatherley use eggnog instead milk make fren...      0.000000  0.000000
# 4  chines french nft enthusiast golden milk lover...      0.250000  0.150000

# %%
French_tweet_df.tail(5)
# Out:
#                                              tweetText  Subjectivity  Polarity
# 571  miguela nedraza cagovernor wtf give chocol mil...      0.500000  0.000000
# 572  upuouo emmanuelmacron mahnazshirali rant canad...      0.033333  0.000000
# 573  elimin diet drop first pork chicken beef egg w...      0.516667  0.070000
# 574  person arab kona turkish latt almond milk pepp...      0.477778 -0.255556
# 575  bela bath amp beauti oatmeal milk amp bran tri...      0.350000 -0.100000

# %%
# function to alnalyse the polarity score
def Analysis(score):
    if score < 0:
        return 'negative'
    elif score == 0:
        return 'neutral'
    else:
        return 'positive'

# %%
#apply the tweet polority to a new column
French_tweet_df['twtsentiment'] = French_tweet_df['Polarity'].apply(Analysis)

# %%
French_tweet_df.head(5)
# Out:
#                                            tweetText  Subjectivity  Polarity  \
# 0  drop milk bellevil christma tree dispensari oi...      0.000000  0.000000
# 1  french delight caf au lait drown caffein crave...      0.497222  0.313889
# 2  french cow milk chees petit livarot oz szvjn u...      0.083333 -0.066667
# 3  kateatherley use eggnog instead milk make fren...      0.000000  0.000000
# 4  chines french nft enthusiast golden milk lover...      0.250000  0.150000
#
#   twtsentiment
# 0      neutral
# 1     positive
# 2     negative
# 3      neutral
# 4     positive

# %% [markdown]
# #### Visualize the polarity result

# %%
##declare variable here
totalTweets=0
positive = 0
negative = 0
neutral = 0
# fucntion to get data and assign to the variables
totalTweets = len(French_tweet_df["twtsentiment"])
for twtsentiment in French_tweet_df["twtsentiment"]:
    if twtsentiment == "negative":
        negative += 1
    elif twtsentiment == "positive":
        positive += 1
    elif twtsentiment == "neutral":
        neutral += 1

# %%
# print results
print("total number: ",totalTweets)
print("positive number: ",positive)
print("negative number: ", negative)
print("neutral number: ",neutral)
# Out:
# total number:  576
# positive number:  168
# negative number:  144
# neutral number:  264

# %%
# function to calculate the percentages
def percentage(part, whole):
    percentage = 100 * float(part)/float(whole)
    
    return ("{:.2f}".format(percentage))

# %%
# calculate percentage
positivePercentage = percentage(positive, totalTweets)
negativePercentage = percentage(negative, totalTweets)
neutralPercentage = percentage(neutral, totalTweets)

# %%
# print values here
print("total tweet: ",totalTweets)
print("positive tweet %: ",positivePercentage)
print("negative tweet %: ", negativePercentage)
print("neutral tweet %: ",neutralPercentage)
# Out:
# total tweet:  576
# positive tweet %:  29.17
# negative tweet %:  25.00
# neutral tweet %:  45.83

# %%
# import library
import matplotlib.pyplot as plt
import seaborn as sns

#Creating PieCart
labels = ['Positive ['+str(positivePercentage)+'%]' , 'Neutral ['+str(neutralPercentage)+'%]','Negative ['+str(negativePercentage)+'%]']
sizes = [positivePercentage,neutralPercentage, negativePercentage]
colors = ['yellowgreen', 'blue','red']
patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(labels)
plt.title("Sentiment Analysis Result for Milk Related Tweets in France" )
plt.axis('equal')
plt.show()

# %%
# Store the column of the dataframe named as "text"
X = French_tweet_df['tweetText']

# %%
# Store the column if the dataframe named as  "airline_sentiment"
y = French_tweet_df['twtsentiment']

# %%
y.head()
# Out:
# 0     neutral
# 1    positive
# 2    negative
# 3     neutral
# 4    positive
# Name: twtsentiment, dtype: object

# %%
# Collect all columns into dataframe named as sentiment_ordering
sentiment_ordering = ['negative', 'neutral', 'positive']

# store all values into column named as "y"
y = y.apply(lambda x: sentiment_ordering.index(x))

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    0
# 3    1
# 4    2
# Name: twtsentiment, dtype: int64

# %% [markdown]
# ### Bag of Words using CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Instantiate an object cv by calling a method named as CountVectorzer()
cv    = CountVectorizer(max_features = 3000, stop_words = ['milk', 'price'])

# Train the dataset by calling a fit_transform() method
X_fin = cv.fit_transform(X).toarray()

# Display the rows and colums
X_fin.shape
# Out:
# (576, 877)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split

# Instantiate an object model by calling a method MultinomialNB()
model = MultinomialNB()

# %%
# Split the dataset into training and testing parts
X_train, X_test, y_train, y_test = train_test_split(X_fin, y, test_size = 0.3)

# %%
# Train the model by calling a method fit()
model.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
# Call predict() method
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# Instantiate a mthod named as Cla
cf = classification_report(y_test, y_pred)

# Display the values of an object cf
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        42
#            1       1.00      1.00      1.00        63
#            2       1.00      1.00      1.00        68
#
#     accuracy                           1.00       173
#    macro avg       1.00      1.00      1.00       173
# weighted avg       1.00      1.00      1.00       173

# %% [markdown]
# ### Feature Generation using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Create an object 'tf' by calling a method TfidfVectorizer()
tfidf = TfidfVectorizer(max_features = 3000, stop_words = ['milk', 'price'])

# Train the dataset by calling a method fit_tranform() 
X_tfidf = tfidf.fit_transform(X).toarray()

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split

# Instantiate an object model by calling a method MultinomialNB()
model_tdidf = MultinomialNB()

# %%
# Split the dataset into training and testing parts
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size = 0.3)

# %%
# Train the model by calling a method fit()
model_tdidf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Call predict() method
y_pred = model_tdidf.predict(X_test)

# %%
from sklearn.metrics import classification_report

# Instantiate a mthod named as Cla
cf = classification_report(y_test, y_pred)

# Display the values of an object cf
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.96        47
#            1       0.95      1.00      0.98        83
#            2       1.00      1.00      1.00        43
#
#     accuracy                           0.98       173
#    macro avg       0.98      0.97      0.98       173
# weighted avg       0.98      0.98      0.98       173
